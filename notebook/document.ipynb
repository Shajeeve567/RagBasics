# %%
### document Structure

from langchain_core.documents import Document

# %%
doc = Document(
    page_content="this is the main text content im using to create RAG",
    metadata={
        "source": "example.txt",
        "pages": 1,
        "author": "Shaj",
        "data_created": "2026-01-01"
    }
)
# metadata is when filtering
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Shaj', 'data_created': '2026-01-01'}, page_content='this is the main text content im using to create RAG')

# %%
### ceate a simple txt file

import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt": """Python Programming Introduction

    Python is a high-level, interpreted programming langugae known for its simplicity and created by 

""",
    "../data/text_files/machine_learning.txt": """Machine Learning Overview

    Machine Learning (ML) is a subset of artificial intelligence focused on building systems that learn from data to improve their performance without being explicitly programmed. It bridges the gap between traditional computer science and statistical analysis, allowing for the creation of predictive models and automated decision-making processes.

    The field is generally divided into three primary paradigms: Supervised Learning, where models learn from labeled data; Unsupervised Learning, which finds hidden patterns in unlabeled data; and Reinforcement Learning, which involves agents learning to make decisions by receiving rewards or penalties. Today, ML powers critical technologies ranging from recommendation engines and natural language processing to computer vision and autonomous systems.

    As a field, it is heavily supported by robust Python frameworks like Scikit-learn for classical algorithms, and TensorFlow or PyTorch for deep learning. Its evolution continues to drive innovation in MLOps, enabling developers to build, deploy, and scale intelligent applications that can adapt to new information in real-time. """
}

for filepath, content in sample_texts.items():
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(content)

print(" Sample text files created!")
# Out:
#  Sample text files created!

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
# automatically the data is converted into document structure(page_contents, metadata)

# %%
### Directory loader

from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False
)

documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Overview\n\n    Machine Learning (ML) is a subset of artificial intelligence focused on building systems that learn from data to improve their performance without being explicitly programmed. It bridges the gap between traditional computer science and statistical analysis, allowing for the creation of predictive models and automated decision-making processes.\n\n    The field is generally divided into three primary paradigms: Supervised Learning, where models learn from labeled data; Unsupervised Learning, which finds hidden patterns in unlabeled data; and Reinforcement Learning, which involves agents learning to make decisions by receiving rewards or penalties. Today, ML powers critical technologies ranging from recommendation engines and natural language processing to computer vision and autonomous systems.\n\n    As a field, it is heavily supported by robust Python framework
# ...

# %%
from langchain_community.document_loaders import PyMuPDFLoader, PyPDFLoader

dir_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    show_progress=False
)

pdf_documents = dir_loader.load()

pdf_documents
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2026-02-07T04:39:02+00:00', 'source': '..\\data\\pdf\\machine_learning_for_rag_dummy.pdf', 'file_path': '..\\data\\pdf\\machine_learning_for_rag_dummy.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-02-07T04:39:02+00:00', 'trapped': '', 'modDate': "D:20260207043902+00'00'", 'creationDate': "D:20260207043902+00'00'", 'page': 0}, page_content='Machine Learning for RAG Systems\nIntroduction\nThis document is a dummy educational PDF designed to be used in a Retrieval-Augmented\nGeneration (RAG) project. It contains foundational machine learning concepts commonly\nreferenced by LLM-powered systems.\nWhat is Machine Learning?\nMachine Learning (ML) is a subset of artificial intelligence where systems learn patterns from data\ninstead of being explicitly programmed.
# ...
